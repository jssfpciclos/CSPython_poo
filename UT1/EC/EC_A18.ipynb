# %% [markdown]
# # UT1. Ejercicios A18. POO en Python: Enumeados
#
# Realiza los siguientes ejercicios para practicar la composición en Python.
#
# **Objetivo**
#
#   Familiarizarse con la importación y uso de módulos y paquetes en Python.
#
# **Recursos**
# - [Documentación Enumerados](../Docs/Doc_enums.ipynb)
#
#
# Estos ejercicios debes realizarlos en Pycharm, creando una carpeta dentro de `EC` llamada `EC_A18`, y para cada ejercicio crea un fichero con el nombre `EjXX.py` dentro de la carpeta, donde XX es el número de ejercicio. Por ejemplo, para el ejercicio 1, el fichero será `Ej01.py`.
#
#
# **Normas base**
#
# A excepción de que se indique lo contrario, se deben cumplir las siguientes normas base:
# - Todos los ejercicios tendrán un fichero `main.py` que será el fichero principal del ejercicio, y estará ubicado en la carpeta raíz del ejercicio.

# %% [markdown]
# ### Ejercicio 1. Enumerados
#
# 1. Definir un enumerado llamado `WeekDays` con los días de la semana, que contenga los días de la semana en español, y en mayúsculas. Cada dia tendrá un valor entero asociado, que será el número de día de la semana, empezando por el lunes con el valor 1.
#    - Incluir una función que indique si un día es laborable o no. Los días laborables son de lunes a viernes.
#    - Incluir una función que devuelva los días fin de semana.
#    - Incluir una función que devuelva los días laborables.
#
# 2. Escribir una función `main` que:
#    - Solicite al usuario que introduzca un día de la semana en número, y obtenga el nombre en texto de ese día. Si el día no existe, debe mostrar un mensaje de error `Número fuera de rango. Debe ser un número entre 1 y 7`.
#    - Recorra todos los días laborales, e imprima el siguiente texto `El día {lunex} es laborable, y es el día nº {1} de la semana`.

# %% [markdown]
# ### Ejercicio 2
#
# 1. Define un enumerado `OperacionAritmeticaEnum` para las operaciones de una calculadora, con las siguientes operaciones: suma, resta, multiplicación, división, potencia, raíz cuadrada. El valor asociado a cada operación no tiene importancia, por lo que se lo debe dejar a Python que lo asigne automáticamente.
# 2. Define una clase `calculadora` que tenga un método de clase `calcular` que reciba como parámetros dos números y una operación aritmética (enumerado), y devuelva el resultado de aplicar la operación a los dos números.
#
# ```python
# # main.py
# class OpAritmeticaEnum(Enum):
#     # Completa este enumerado
#     pass
#
# class Calculadora:
#     @staticmethod
#     def calcular(num1, num2, operacion):
#         # Completa este método
#         pass
# ```
#
# así, si ejecutamos el siguiente código:
#
# ```python
# # main.py
# assert Calculadora.calcular(2, 3, OpAritmeticaEnum.SUMA) == 5
# assert Calculadora.calcular(2, 3, OpAritmeticaEnum.RESTA) == -1
# assert Calculadora.calcular(2, 3, OpAritmeticaEnum.MULTIPLICACION) == 6
# assert Calculadora.calcular(3, 3, OpAritmeticaEnum.DIVISION) == 1
# assert Calculadora.calcular(2, 3, OpAritmeticaEnum.POTENCIA) == 8
# assert Calculadora.calcular(2, 3, OpAritmeticaEnum.RAIZ_CUADRADA) == 1.4142135623730951
# ```

# %% [markdown]
# ### Ejercicio 4. Enumerados permitan comparación numérica
#
# 1. Define un enumerado tipo IntEnum llamado `NivelAccesoEnum` con lo siguientes valores `SIN_ACCESO=0, RESTRINGIDO=2, NORMAL=3, TOTAL=3`
#   - Incluir un método en el enumerado para validar si un `usuario` tiene acceso según un nivel de Acceso especifico. Devolver True/False.
# 2. Definie un enumerado `ModuloEnum` para los módulos de un programa ERP con los siguientes valores: `VENTAS=1, COMPRAS=2, ALMACEN=4, CONTABILIDAD=8, RRHH=16, ADMINISTRACION=32, DIRECCION=64` (tipo IntEnum y Flag)
#   - Incluir un método en el enumerado para validar si un `usuario` tiene acceso a un módulo especifico. Devolver True/False.
# 3. Define una clase UserAuth, con los siguientes atributos: `nombre` y `login`.
#   - Por defecto, un usuario no tiene acceso a ningún módulo.
#   - Almacena el nivel de acceso para un módulo en un diccionario, donde la clave es el módulo y el valor es el nivel de acceso.
#   - Incluye un método `get_module_access_level` que recibe un módulo y devuelve el nivel de acceso del usuario a ese módulo. Si el usuario no tiene acceso al módulo, devuelve `SIN_ACCESO`.
#   - Incluye un método `assing_all_module_access` para asignar todos los accesos a los módulos, que recibe una lista de tuplas con el módulo y el nivel de acceso.
#   - Incluye un método `asisgn_module_access` para añadir un módulo y nivel de acceso a un usuario.
#   - Incluye un método `unassing_module_access` para eliminar un módulo de un usuario. (Si un usuario no tiene acceso a un módulo, se devuelve `SIN_ACCESO`)
#   total, y False en caso contrario.
#   - Incluye un método `reset_module_access` para eliminar todos los módulos de un usuario.
#   - Incluye un método `has_module_access` para comprobar si un usuario tiene acceso a un módulo con un nivel de acceso. Devuelve True si el usuario tiene acceso al módulo con el nivel de acceso indicado, False en caso contrario.
#
# Comprobar que funciona correctamente con el siguiente código:
#
# ```python
# # main.py
# class NivelAccesoEnum(IntEnum):
#   # Completa este enumerado
#
#   def verificar_acceso(self, nivel_acceso_usuario: NivelAccesoEnum, nivel_acceso_check: NivelAccesoEnum) -> bool:
#       # Completa este método, utilizando los operadores de comparación. Si el nivel de acceso es mayor o igual, devuelve True, en caso contrario, False
#       pass
#   pass
#
# class ModuloEnum(IntFlag):
#   # Completa este enumerado
#   pass
#
# class UserAuth:
#   def __init__(self, nombre: str, login: str):
#       self.nombre = nombre
#       self.login = login
#
#   def get_module_access_level(self, module: ModuloEnum) -> NivelAccesoEnum:
#     # Completa este método
#     pass
#
#   def assing_all_module_access(self, modules: List[Tuple[ModuloEnum, NivelAccesoEnum]]):
#     # Completa este método
#     pass
#
#   def asisgn_module_access(self, module: ModuloEnum, nivel_acceso: NivelAccesoEnum):
#     # Completa este método
#     pass
#
#   def unassing_module_access(self, module: ModuloEnum):
#     # Completa este método
#     pass
#
#   def reset_module_access(self):
#     # Completa este método
#     pass
#
#   def is_module_access(self, module: ModuloEnum) -> bool:
#     # Completa este método
#     pass
#
#   def has_module_access(self, module: ModuloEnum, nivel_acceso: NivelAccesoEnum) -> bool:
#     # Completa este método. True si el usuario tiene acceso al módulo con el nivel de acceso indicado, False en caso contrario
#     pass
#
# # Código de prueba
#
# user1 = UserAuth("Juan", "juanin")
# user1.assing_all_module_access([(ModuloEnum.VENTAS, NivelAccesoEnum.NORMAL), (ModuloEnum.COMPRAS, NivelAccesoEnum.RESTRINGIDO)])
# assert user1.is_module_access(ModuloEnum.VENTAS) == True
# assert user1.is_module_access(ModuloEnum.COMPRAS) == True
# assert user1.is_module_access(ModuloEnum.ALMACEN) == False
#
# user1.unassing_module_access(ModuloEnum.VENTAS)
# assert user1.is_module_access(ModuloEnum.VENTAS) == False
#
# user1.reset_module_access()
# assert user1.is_module_access(ModuloEnum.VENTAS) == False
# assert user1.is_module_access(ModuloEnum.COMPRAS) == False
#
# user1.assign_module_access(ModuloEnum.COMPRAS, NivelAccesoEnum.TOTAL)
# user1.assign_module_access(ModuloEnum.VENTAS, NivelAccesoEnum.NORMAL)
# assert user1.has_module_access(ModuloEnum.VENTAS, NivelAccesoEnum.NORMAL) == True
# assert user1.has_module_access(ModuloEnum.VENTAS, NivelAccesoEnum.RESTRINGIDO) == False
# assert user1.has_module_access(ModuloEnum.COMPRAS, NivelAccesoEnum.NORMAL) == False
# ```

# %% [markdown]
# ### Ejercicio 3.  Enumerado tipo Flag
#
# 1. Define un enumerado `PermisoFicheroEnum` que defina los permisos de un fichero: lectura, escritura, ejecución. (tipo Flag)
#    - Lectura=1, Escritura=2, Ejecucion=4.
#    - Que además tenga las combinaciones, `todos=7, ninguno=0`.
#    - Tenga un método para obtener el valor textual del permiso. (Lectura=r, Escritura=w, Ejecucion=x). `get_permisoLetra`
#
# 2. Define un enumerado `PermisoOpcionEnum` que defina las partes de un permiso en linux: usuario, grupo, otros.
# 3. Define una clase `PermisoFichero` que almacene, el nombre y ruta del fichero, y los permisos por usuario, grupo y otros.
#    - El constructor recibirá la ruta del fichero, y los permisos en formato `-rwxrwxrwx`, donde cada letra indica si el permiso está activo o no. Por ejemplo, `-rwxrwx---` indica que el usuario tiene permisos de lectura, escritura y ejecución, y el grupo tiene todos y otros no tiene ninguno.
#    - Almacenar cada parte del permiso (Usuario, Grupo y Otros) en un diccionario, donde la clave sea el enumerado `PermisoOpcionEnum`, y el valor sea un enumerado `PermisoFicheroEnum`.
#
#    Métodos:
#    - `get_permiso` que reciba como parámetro un enumerado `PermisoOpcionEnum`, y devuelva el permiso asociada a esa opción en formato `PermisoFicheroEnum`.
#    - `get_permisoNumerico` que devuelva el permiso en formato numérico, por ejemplo, `764`.
#    - `set_permiso` que reciba como parámetros:
#      - O bien, una lista de tuplas, donde cada tupla tenga el enumerado `PermisoOpcionEnum` y el enumerado `PermisoFicheroEnum`, y actualice los permisos del fichero.
#      - O biem, un string con el formato `-rwxrwxrwx`, y actualice los permisos del fichero.
#
# ```python
# # main.py
# class PermisoFicheroEnum(Enum):
#     # Completa este enumerado
#     pass
#
# class PermisoOpcionEnum(Enum):
#    # Completa este enumerado
#    pass
#
#
# class PermisoFichero:
#     def __init__(self, ruta, permisos):
#         # Completa este método
#         pass
#
#     def get_permiso(self, opcion: PermisoOpcionEnum) -> PermisoFicheroEnum:
#         # Completa este método
#         pass
#
#     def get_permisoNumerico(self) -> int:
#         # Completa este método
#         pass
#
#     def set_permiso(self, permisos: List[Tuple[PermisoOpcionEnum, PermisoFicheroEnum]] | str):
#         # Completa este método
#         pass
#
#
# # Comprobaciones de funcionamiento
# ficheroPermisos = PermisoFichero("fichero.txt", "-rwxrwx--x")
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.USUARIO) in PermisoFicheroEnum.ESCRITURA
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.GRUPO) in PermisoFicheroEnum.LECTURA
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.OTROS) in PermisoFicheroEnum.EJECUCION
# assert ficheroPermisos.get_permisoNumerico() == 770
#
# ficheroPermisos.set_permiso("-rwx---rwx")
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.USUARIO) in PermisoFicheroEnum.TODOS
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.GRUPO) in PermisoFicheroEnum.NINGUNO
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.OTROS) in PermisoFicheroEnum.TODOS
#
# ficheroPermisos.set_permiso([
#     (PermisoOpcionEnum.USUARIO, PermisoFicheroEnum.LECTURA | PermisoFicheroEnum.EJECUCION),
#     (PermisoOpcionEnum.GRUPO, PermisoFicheroEnum.EJECUCION),
#     (PermisoOpcionEnum.OTROS, PermisoFicheroEnum.NINGUNO)
# ])
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.USUARIO) in PermisoFicheroEnum.LECTURA | PermisoFicheroEnum.EJECUCION
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.GRUPO) in PermisoFicheroEnum.EJECUCION
# assert ficheroPermisos.get_permiso(PermisoOpcionEnum.OTROS) in PermisoFicheroEnum.NINGUNO
# ```
